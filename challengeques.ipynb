# %% [markdown]
# <a href="https://colab.research.google.com/github/deepvirk7/SORTING-LIST-OF-HETROGENOUS-DATA/blob/main/challengeques.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Challenge Question ![image.png](data:image/png;base64,...)

# %%
L = ["Ram", 1, "Shyam", 2, "Aman", 3]
print(L)
L.sort()
print(L)
# Out:
# ['Ram', 1, 'Shyam', 2, 'Aman', 3]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-3736938767> in <cell line: 0>()
#       1 L = ["Ram", 1, "Shyam", 2, "Aman", 3]
#       2 print(L)
# ----> 3 L.sort()
#       4 print(L)
#
# TypeError: '<' not supported between instances of 'int' and 'str'

# %%
L = ["Ram", 1, "Shyam", 2, "Aman", 3]
print("original list:",L)
print("we can sort the hetrogeneous elements by converting them into string.")
L = [str(item) for item in L]
L.sort()
print("sorted list :",L)
# Out:
# original list: ['Ram', 1, 'Shyam', 2, 'Aman', 3]
# we can sort the hetrogeneous elements by converting them into string.
# sorted list : ['1', '2', '3', 'Aman', 'Ram', 'Shyam']
